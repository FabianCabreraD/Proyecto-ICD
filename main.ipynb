# %%
import icd_module as icd

# %% [markdown]
# ![](img/data1.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.currency_graph()

# %% [markdown]
# ![](img/data2.png)

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.salary_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.salary_cuba_vs_america()

# %% [markdown]
# <h1>Tabla</h1>

# %%
icd.table()
# Out:
# 445
# 498

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# <h1>Gráfico 5</h1>

# %%
icd.egg_employees_graph()

# %% [markdown]
# <h1>Gráfico 6</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 7</h1>

# %%
icd.milk_beans_minpens()

# %% [markdown]
# <h1>Gráfico 8</h1>

# %%
icd.liquids_graph()

# %% [markdown]
# <h1>Gráfico 9</h1>

# %%
icd.beer_graph()

# %% [markdown]
# <h1>Mapa</h1>

# %%
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a879f487a15f52e8dfa4803df298809c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a879f487a15f52e8dfa4803df298809c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a879f487a15f52e8dfa4803df298809c = L.map(
#                 &quot;map_a879f487a15f52e8dfa4803df298809c&quot;,
#                 {
#                     center: [23.07088, -82.43847],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ad6d61d747fbf28b1f1b5f96295eb94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ad6d61d747fbf28b1f1b5f96295eb94.addTo(map_a879f487a15f52e8dfa4803df298809c);
#
#
#             var marker_a716e51195e2d521c21c70ed43e9c5b5 = L.marker(
#                 [23.080402, -82.422601],
#                 {
# }
#             ).addTo(map_a879f487a15f52e8dfa4803df298809c);
#
#
#         var custom_icon_bf8ae7e7408d865bc2384c2f1e23729c = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_a716e51195e2d521c21c70ed43e9c5b5.setIcon(custom_icon_bf8ae7e7408d865bc2384c2f1e23729c);
#
#
#         var popup_83e66ac2c560694e3de760f9612bb0a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab3c9ccd34a0d183c78385abd48467af = $(`&lt;div id=&quot;html_ab3c9ccd34a0d183c78385abd48467af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;51 E/100 y 102&lt;/h1&gt;             &lt;p&gt;No alcanza para ningún líquido&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_83e66ac2c560694e3de760f9612bb0a4.setContent(html_ab3c9ccd34a0d183c78385abd48467af);
#
#
#
#         marker_a716e51195e2d521c21c70ed43e9c5b5.bindPopup(popup_83e66ac2c560694e3de760f9612bb0a4)
#         ;
#
#
#
#
#             marker_a716e51195e2d521c21c70ed43e9c5b5.bindTooltip(
#                 `&lt;div&gt;
#                      51 E/100 y 102
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c6c423734ef396a524da1a3d610061e4 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_a879f487a15f52e8dfa4803df298809c);
#
#
#         var custom_icon_bd2795f692f3f99fc69bfa79f81c3c2a = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_c6c423734ef396a524da1a3d610061e4.setIcon(custom_icon_bd2795f692f3f99fc69bfa79f81c3c2a);
#
#
#         var popup_d1daa1dfbe9f96943292a28ea85b85bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3113f15da23cdb9d80ce0bdfa1b16c98 = $(`&lt;div id=&quot;html_3113f15da23cdb9d80ce0bdfa1b16c98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;1005&lt;/h1&gt;             &lt;p&gt;No alcanza para ningún líquido&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_d1daa1dfbe9f96943292a28ea85b85bd.setContent(html_3113f15da23cdb9d80ce0bdfa1b16c98);
#
#
#
#         marker_c6c423734ef396a524da1a3d610061e4.bindPopup(popup_d1daa1dfbe9f96943292a28ea85b85bd)
#         ;
#
#
#
#
#             marker_c6c423734ef396a524da1a3d610061e4.bindTooltip(
#                 `&lt;div&gt;
#                      1005
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43da8b0828be86a95f603f0916b726db = L.marker(
#                 [23.076548, -82.42704],
#                 {
# }
#             ).addTo(map_a879f487a15f52e8dfa4803df298809c);
#
#
#         var custom_icon_9fda2cfe535dc91daa90948d926adb4d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_43da8b0828be86a95f603f0916b726db.setIcon(custom_icon_9fda2cfe535dc91daa90948d926adb4d);
#
#
#         var popup_fb62ea6a3b4ce153838a9c40ea5b1ead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb4f135d5b7aef2d324233357ffdc1f = $(`&lt;div id=&quot;html_4bb4f135d5b7aef2d324233357ffdc1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;49 E/112 y 114&lt;/h1&gt;             &lt;p&gt;Jugo&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_fb62ea6a3b4ce153838a9c40ea5b1ead.setContent(html_4bb4f135d5b7aef2d324233357ffdc1f);
#
#
#
#         marker_43da8b0828be86a95f603f0916b726db.bindPopup(popup_fb62ea6a3b4ce153838a9c40ea5b1ead)
#         ;
#
#
#
#
#             marker_43da8b0828be86a95f603f0916b726db.bindTooltip(
#                 `&lt;div&gt;
