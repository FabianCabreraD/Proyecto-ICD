# %%
import icd_module as icd

# %% [markdown]
# ![](img/data1.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.full_currency_graph()

# %% [markdown]
# ![](img/data2.png)

# %%
icd.means_table()
# Out:
# +--------------------+-------+-------+
# |  Últimos 3 meses   |  USD  |  EURO |
# +--------------------+-------+-------+
# |   Salario Medio    | 15.24 | 13.65 |
# |   Pensión Mínima   |  6.99 |  6.26 |
# | Estipendio 1er Año |  0.46 |  0.41 |
# +--------------------+-------+-------+

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.egg_employees_graph()

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 5</h1>

# %%
icd.milk_beans_minpens()

# %% [markdown]
# <h1>Gráfico 6</h1>

# %%
icd.liquids_graph()
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35e3903ecff07d2088f387b34126e063 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35e3903ecff07d2088f387b34126e063&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35e3903ecff07d2088f387b34126e063 = L.map(
#                 &quot;map_35e3903ecff07d2088f387b34126e063&quot;,
#                 {
#                     center: [23.07088, -82.43847],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6c845a4a80a1db03954f713f806fd7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b6c845a4a80a1db03954f713f806fd7d.addTo(map_35e3903ecff07d2088f387b34126e063);
#
#
#             var marker_88a4c57d44258cd6c4d72606502035f3 = L.marker(
#                 [23.080402, -82.422601],
#                 {
# }
#             ).addTo(map_35e3903ecff07d2088f387b34126e063);
#
#
#         var custom_icon_16e7b4a86acefad05eee16633050ed8c = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_88a4c57d44258cd6c4d72606502035f3.setIcon(custom_icon_16e7b4a86acefad05eee16633050ed8c);
#
#
#         var popup_fc25896ffae58316e2ec6498deea08fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8225ff17257b052df9829b28c84a09e = $(`&lt;div id=&quot;html_d8225ff17257b052df9829b28c84a09e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;None&lt;/h1&gt;             &lt;p&gt;No alcanza para ningún líquido&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_fc25896ffae58316e2ec6498deea08fc.setContent(html_d8225ff17257b052df9829b28c84a09e);
#
#
#
#         marker_88a4c57d44258cd6c4d72606502035f3.bindPopup(popup_fc25896ffae58316e2ec6498deea08fc)
#         ;
#
#
#
#
#             var marker_38a8020c0f135e79dcce65c9129dc2b3 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_35e3903ecff07d2088f387b34126e063);
#
#
#         var custom_icon_a87eac3a31e9a1441466cb50257b8a13 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_38a8020c0f135e79dcce65c9129dc2b3.setIcon(custom_icon_a87eac3a31e9a1441466cb50257b8a13);
#
#
#         var popup_834936e6983c6a7e9d4c29845036b183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a01a514db04facb0e591b1bece24a4d6 = $(`&lt;div id=&quot;html_a01a514db04facb0e591b1bece24a4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;1005&lt;/h1&gt;             &lt;p&gt;No alcanza para ningún líquido&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_834936e6983c6a7e9d4c29845036b183.setContent(html_a01a514db04facb0e591b1bece24a4d6);
#
#
#
#         marker_38a8020c0f135e79dcce65c9129dc2b3.bindPopup(popup_834936e6983c6a7e9d4c29845036b183)
#         ;
#
#
#
#
#             marker_38a8020c0f135e79dcce65c9129dc2b3.bindTooltip(
#                 `&lt;div&gt;
#                      1005
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0eb0faddedd06a427177e368fd3198d1 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_35e3903ecff07d2088f387b34126e063);
#
#
#         var custom_icon_7210c85d4e8f634da9fc01e759e0e988 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_0eb0faddedd06a427177e368fd3198d1.setIcon(custom_icon_7210c85d4e8f634da9fc01e759e0e988);
#
#
#         var popup_92d08be677664b20c0b21e4a56696760 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05078b36c230106d62c0315eebda6d5a = $(`&lt;div id=&quot;html_05078b36c230106d62c0315eebda6d5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;None&lt;/h1&gt;             &lt;p&gt;No alcanza para ningún líquido&lt;/p&gt;         &lt;/div&gt;`)[0];
#                 popup_92d08be677664b20c0b21e4a56696760.setContent(html_05078b36c230106d62c0315eebda6d5a);
#
#
#
#         marker_0eb0faddedd06a427177e368fd3198d1.bindPopup(popup_92d08be677664b20c0b21e4a56696760)
#         ;
#
#
#
#
#             var marker_26087a8654b2ef599f68b0ebc53b119e = L.marker(
#                 [23.081575, -82.422475],
#                 {
# }
#             ).addTo(map_35e3903ecff07d2088f387b34126e063);
#
#
#         var custom_icon_81b72cff47f619ae5585726339191490 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconS

# %%
import os
json = icd.mipymes_list()
evidencia = len(os.listdir("evidencia/"))
# for i in json:
#     path = icd.path_mipyme(i)
#     data = icd.read_json(path)
#     for j in data["product"]:
#         if j["type"] in ["Refresco", "Cerveza", "Jugo", "Malta"] and isinstance(j["price"],str):
#             print(i)
print(len(json))
print(evidencia)
# Out:
# 30
# 26
