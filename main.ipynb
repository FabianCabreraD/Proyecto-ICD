# %%
import icd_module as icd

# %% [markdown]
# ![](img/data1.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.currency_graph()

# %% [markdown]
# ![](img/data2.png)

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.salary_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.salary_cuba_vs_america()

# %% [markdown]
# <h1>Tabla</h1>

# %%
icd.table()

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# <h1>Gráfico 5</h1>

# %%
icd.egg_employees_graph()

# %% [markdown]
# <h1>Gráfico 6</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 7</h1>

# %%
icd.milk_beans_minpens()

# %% [markdown]
# <h1>Gráfico 8</h1>

# %%
icd.liquids_graph()

# %% [markdown]
# <h1>Gráfico 9</h1>

# %%
icd.beer_graph()

# %% [markdown]
# <h1>Mapa</h1>

# %%
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import os
json = icd.mipymes_list()
evidencia = os.listdir("evidencia/")

for i in json:
    string = i.replace(".json","")
    if string not in evidencia:
        print(i)


# for i in json:
#     path = icd.path_mipyme(i)
#     data = icd.read_json(path)
#     for j in data["product"]:
#         if j["type"] in ["Refresco", "Cerveza", "Jugo", "Malta"] and isinstance(j["price"],str):
#             print(i)
print(len(json))
print(len(evidencia))
# Out:
# Andrea.json
# I y J.json
# La Favorita.json
# Oasis.json
# 34
# 30
