# %%
import icd_module as icd

# %% [markdown]
# ![](img/salary_pension.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.currency_graph()
icd.salary_and_pension_graph()

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.full_rice_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.liquids_graph()
