# %%
import icd_module as icd

# %% [markdown]
# ![](img/data.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.full_currency_graph()

# %% [markdown]
# ![](img/data2.png)

# %%
icd.means()
# Out:
# Últimos 3 Meses
# --------------------------------------------
# Precio promedio de USD: 437
# Precio promedio de EUR: 489
# Promedio Salario Medio en USD: 15.24
# Promedio Salario Medio en EUR: 13.62
# Promedio Pensión Mínima en USD: 6.99
# Promedio Pensión Mínima en EUR: 6.25
# Promedio Estipendio 1er Año en USD: 0.46
# Promedio Estipendio 1er Año en EUR: 0.41

# %% [markdown]
# ![](img/data3.png)

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.liquids_graph()
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a1b6fb0fe5c0def7b17143f772b3d71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a1b6fb0fe5c0def7b17143f772b3d71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a1b6fb0fe5c0def7b17143f772b3d71 = L.map(
#                 &quot;map_6a1b6fb0fe5c0def7b17143f772b3d71&quot;,
#                 {
#                     center: [23.0515757, -82.3304645],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_892c3dafc151fcbb968e03194469f575 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_892c3dafc151fcbb968e03194469f575.addTo(map_6a1b6fb0fe5c0def7b17143f772b3d71);
#
#
#             var marker_26b00bb325faf9ed9abb19d1f29efed7 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_6a1b6fb0fe5c0def7b17143f772b3d71);
#
#
#         var custom_icon_33d670b6f8bdd7292df2b80dc5ec8e43 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_26b00bb325faf9ed9abb19d1f29efed7.setIcon(custom_icon_33d670b6f8bdd7292df2b80dc5ec8e43);
#
#
#         var popup_e758bdb25cb4bfb674bc6f7ee110027f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7b91846e45cc1a62d1094217a3c1dd0 = $(`&lt;div id=&quot;html_a7b91846e45cc1a62d1094217a3c1dd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;1005&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_e758bdb25cb4bfb674bc6f7ee110027f.setContent(html_a7b91846e45cc1a62d1094217a3c1dd0);
#
#
#
#         marker_26b00bb325faf9ed9abb19d1f29efed7.bindPopup(popup_e758bdb25cb4bfb674bc6f7ee110027f)
#         ;
#
#
#
#
#             marker_26b00bb325faf9ed9abb19d1f29efed7.bindTooltip(
#                 `&lt;div&gt;
#                      1005
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_94a3a55d0e3f525e0d6491b7f933f76d = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_6a1b6fb0fe5c0def7b17143f772b3d71);
#
#
#         var custom_icon_48008195d7ac50a13922b8b55eca967b = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_94a3a55d0e3f525e0d6491b7f933f76d.setIcon(custom_icon_48008195d7ac50a13922b8b55eca967b);
#
#
#         var popup_23b2e19d8bbafda53a183b725091c753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_626adb887d7f955f5220aa2622936e49 = $(`&lt;div id=&quot;html_626adb887d7f955f5220aa2622936e49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;None&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_23b2e19d8bbafda53a183b725091c753.setContent(html_626adb887d7f955f5220aa2622936e49);
#
#
#
#         marker_94a3a55d0e3f525e0d6491b7f933f76d.bindPopup(popup_23b2e19d8bbafda53a183b725091c753)
#         ;
#
#
#
#
#             var marker_8c2412b37aac29bcfb200af501d93b6d = L.marker(
#                 [23.127062, -82.399987],
#                 {
# }
#             ).addTo(map_6a1b6fb0fe5c0def7b17143f772b3d71);
#
#
#         var custom_icon_46026a0524d53df07d1c80274aecc5df = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_8c2412b37aac29bcfb200af501d93b6d.setIcon(custom_icon_46026a0524d53df07d1c80274aecc5df);
#
#
#         var popup_7a9f33432d079affe22bb105200190ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9005765010ffa67f7efeb6739bfc53d9 = $(`&lt;div id=&quot;html_9005765010ffa67f7efeb6739bfc53d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;Andrea&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_7a9f33432d079affe22bb105200190ce.setContent(html_9005765010ffa67f7efeb6739bfc53d9);
#
#
#
#         marker_8c2412b37aac29bcfb200af501d93b6d.bindPopup(popup_7a9f33432d079affe22bb105200190ce)
#         ;
#
#
#
#
#             marker_8c2412b37aac29bcfb200af501d93b6d.bindTooltip(
#                 `&lt;div&gt;
#                      Andrea
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6d3543281fab7dc699683e21c1d4c989 = L.marker(
#                 [23.142964, -82.386882],
#                 {
# }
#             ).addTo(map_6a1b6fb0fe5c0def7b17143f772b3d71);
#
#
#         var custom_icon_e99c30589cb5e762bceb5d764bbca0eb = L.icon({
#   &quot;iconUrl&quot;: &

# %% [markdown]
# ![](img/m2.png)

# %% [markdown]
# <h1>Gráfico 5</h1>

# %%
icd.egg_employees_graph()

# %% [markdown]
# <h1>Gráfico 6</h1>

# %%
# import os
# import json

# files = os.listdir("data/mipymes")

# for i in files:
#     path = f"data/mipymes/{i}"
#     with open(path,"r",encoding="utf-8") as file:
#         data = json.load(file)
#         for j in data["product"]:
#             if j["type"] == "Huevo":
#                 # j["type"] = "Frijol"
#                 print(i)
#     with open(path,"w",encoding="utf-8") as file:
#         json.dump(data,file,ensure_ascii=False,indent=4)
# Out:
# D'Lucy.json
# El Picotazo.json
# Hurón Azul.json
# I y H.json
# L y M.json
# La Complicidad.json
# La Favorita.json
# Paso a Paso.json
# Tranys.json
