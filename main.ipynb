# %%
import icd_module as icd

# %% [markdown]
# # Proyecto ICD #

# %% [markdown]
# Nos encontramos en el cierre del 2025, ha sido un año **muy complicado** para la economía cubana. Los ingresos del país han reducido considerablemente, consecuencia directa de aspectos como:
# - Exportaciones mínimas
# - Producción nacional prácticamente nula
# - Imposibilidades de pagos en transferencias internacionales debido a restricciones de los EEUU
# - Devaluación constante de la moneda
#
# Este último aspecto es uno de los que más ha golpeado a nuestro país y afecta directamente al cubano de a pie. Ha traído aumento considerable de los precios de los productos de primera necesidad en un momento donde el mecanismo de subsidio del estado es cada vez más débil.
#
# Todo cubano tiene muy claro que: el salario estatal no alcanza para una vida, llamésmole "como Dios manda", mucho menos la pensión de nuestros jubilados, los cuales representan la mayor parte de nuestra población y además nuestros estudiantes universitarios, los llamados a ser el futuro, cuentan con un estipendio infímo. ¿Impacto de estos hechos? Masiva emigración, pérdida del talento, descontento del pueblo, reducción del personal en el sector estatal, entre otros.
#
# Estaré trabajando sobre todo con los siguientes datos mensuales: *Salario Medio*, *Pensión Mínima*, *Estipendio Universitario de Primer Año*, (Fuente: ONEI) los cuales presento en la siguiente imagen:

# %% [markdown]
# ![](img/data1.png)

# %% [markdown]
# Antes mencionamos la devaluación de la moneda nacional (CUP) frente a monedas internacionales de gran impacto financiero como lo son el dólar americano (USD) y el euro (EUR). El mercado cambiario informal de cuba se rige por la tasa publicada por la página elToque (https://eltoque.com/). En la siguiente gráfica se muestra la inestabilidad del precio de venta de USD y EUR con respecto al CUP en el período Septiembre-Diciembre, donde se muestra un crecimiento constante desde Septiembre a pasado la mitad de Octubre llegando a picos nunca antes alcanzados, luego comenzó un descenso y falta de esatbilidad debido a las presiones realizadas por el gobierno contra la plataforma y por último una estabilidad a finales de diciembre quizás marcada por la nueva tasa oficial del gobierno la cual no es muy diferente a la de dicha plataforma.

# %%
icd.currency_graph()

# %% [markdown]
# Después de este análisis podemos resumir el precio de compra en CUP de USD y EUR en el periodo que estamos analizando, lo muestro en la siguiente imagen:

# %% [markdown]
# ![](img/data2.png)

# %% [markdown]
# Ya contamos con datos importantes, ahora pasemos "al pollo del arroz con pollo", conocemos la importancia de las monedas internacionales hoy en día en nuestro país, la mayoría de productos que vende el Estado son en tiendas de pagos en divisas y en el sector privado los precios se rigen tambien según el cambio del dólar e incluso estos aceptan la mayoría pagos tambien en dichas divisas.
#
# Entonces no solo queremos saber cómo ha variado las divisas en el periodo, sino **cómo han variado nuestros ingresos**, miremos la siguiente gráfica:

# %%
icd.salary_graph()

# %% [markdown]
# Para resumir los datos, veamos sus promedios en el rango de tiempo que analizo:
#
# PD: Excel nunca muere

# %% [markdown]
# ![](img/table.png)

# %% [markdown]
# ### Salario Medio

# %% [markdown]
# Pasemos al primer aspecto a analizar en este proyecto, seguramente el más importante y voy a comenzar analizando la posición de nuestro salario medio con respecto a este dato en un grupo de países de América, extraídos de fuentes de estadísticas oficiales de dichos paises citadas en data/sources.txt.

# %%
icd.salary_cuba_vs_america()

# %% [markdown]
# Se puede observar qué tan inferior es el salario medio de nuestro país en USD con respecto a países de nuestra región. El salario de El salvador, penúltimo en este listado, es 20 veces más que el nuestro.
#
# Dicho dato no nos deja claro del todo la situacion económica de cada país, lo que realmente nos lo muestra es el alcance de nuestro salario.
#
# Para esto, hemos reunido precios de un grupo de productos en más de 30 Mipymes de la provincia Habana, en 4 de sus municipios (La Lisa, Marianao, Playa, Plaza de la Revolución).
#
# Sin dudas uno de los productos más consumidos por el cubano es el arroz, producto que siempre ha sido subsidiado por el gobierno cubano, pero en los últimos años, la poca disponibilidad ha obligado a las personas a adquirlo en el sector privado, en el cual presenta un precio enormemente superior.
#
# En el siguiente gráfico se muestra el precio promedio de 1kg de arroz en los países antes analizados y qué por ciento representa del salario medio

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# Creo que está bastante claro, incluso habiendo países donde el precio es superior, el por ciento sobre el salario medio en Cuba es abrumador en comparación con el resto. 1kg de arroz es más que el 10% del salario medio. Dato increíble.
#
# Ahora analizando solo el contexto nacional, pasaremos a otro producto bastante consumido por los cubanos: el huevo, específicamente un cartón, lo que equivale a 30 unidades.
#
# Dicho análisis lo realicé por sector de trabajo, mostrando el por ciento del salario que equivale el precio de un cartón de huevo en cada uno ordenado descendentemente.
#
# En este gráfico además muestro datos de la ONEI, de la variación de empleados del 2024 al 2025 de cada sector y resalto por su importancia, sectores claves dentro de un país como lo son: Educación, Salud y Agricultura, ganadería.

# %%
icd.egg_employees_graph()

# %% [markdown]
# Del gráfico anterior, muchas conclusiones, sectores donde más del 50 por ciento de su salario equivale a un cartón de huevos, pero no solo eso, algunos de estos mismos sectores presentan disminución de su número de trabajadores de hasta mas de 9% (solo 2 sectores presentan incrementos), con un pico en Agricultura, ganadería, caza y sivicultura, con 13.46%, sector clave en la producción nacional y el incremento de disponibilidad de alimentos.

# %% [markdown]
# ### Pensión Mínima

# %% [markdown]
# Volvamos al tema del arroz pero ahora con otro sector de la población, nuestros jubilados, los cuales cuentan con una pensión mínima de 3056 CUP, realmente tomo este dato, porque es la pensión de mi abuela y sé lo insignificante que resulta.
#
# Ahora no tomaremos 1kg de arroz sino la cuota mensual subsidiada de arroz por persona establecida por el gobierno, 7 libras.
#
# En el siguiente gráfico mostramos el precio promedio de 7 libras de arroz en el sector privado y el gran margen que existe entre este y el precio normado.

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# Tomamos ahora otro par de productos:
#
# - Leche: producto muy común en dietas médicas en las personas de la tercera edad.
# - Frijoles: producto subsidiado por el gobierno y alimento que según estudios puede ayudar a controlar el colesterol y la presión arterial.
#
# De ambos tomaremos 1kg

# %%
icd.milk_beans_minpens()

# %% [markdown]
# Otro resultado aplastante, con la compra de 1kg de frijol y 1kg de leche, todo aquella persona que tenga la pensión mínima, solo le quedaría el 5.5% de su pensión, unos 168 pesos, lo cual es menor que una libra de arroz. Tarea difícil la de un pensionado en manejar sus gastos

# %% [markdown]
# ### Estipendio Universitario 1er Año

# %% [markdown]
# Vivimos en un país caribeño, donde existe un verano bien marcado y las altas temperaturas predominan durante casi todo el año. Estas condiciones de calor son, por decirlo de alguna forma, "soportadas" por el consumo de líquidos claramente como el agua, pero además de jugos, refrescos, cervezas, maltas, entre otros.
#
# En el siguiente gráfico se muestra el promedio de precio de dichos productos en las mipymes que visitamos.

# %%
icd.liquids_graph()

# %% [markdown]
# Dato triste para los universitarios de primer año, como yo, a los cuales no nos alcanza nuestro estipendio ni siquiera para **una unidad** de estos productos tan refrescantes.
#
# Por cierto, hablando de productos refrescantes, tuve la suerte de que en un día que estaba buscando datos de mipymes, mi mamá me halla comprado un pote de helado de chocolate con una cuchara muy usada en Cuba.

# %% [markdown]
# ![](img/ice_cream.png)

# %% [markdown]
# Volviendo a los temas de líquidos, quise especificar en las cervezas y una comparación entre aquellas que son nacionales contra las que son importadas, teniendo 2 resultados:
#
# - Precio de cervezas nacionales bien superior a las cervezas importadas (poca producción nacional -> altos precios)
# - Haría falta incrementar en un 33% nuestro estipendio para lograr comprarnos una cerveza importada y en un casi 60% (sí, más de la mitad) para comprarnos, por ejemplo, una Cristal. (para el cumpleaños, no es que seamos borrachos)

# %%
icd.beer_graph()

# %% [markdown]
# Por si es tu cumpleaños pronto y quieres comprarte una cerveza, o simplemente has sudado mucho, te muestro un mapa donde están marcadas las mipymes que visité, clasificándolas en 2 grupos, las que puedes comprarte algún líquido con el estipendio y en las que no.
#
# Recomendación: salir del Vedado si tienes sed.

# %%
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Mi análisis ha llegado a su fin, otras muchas cosas pueden seguir siendo analizadas en el futuro.
#
# Lo cierto es que un grupo de factores ha complejizado la situación económica nacional y nos han llevado a este punto crítico de los precios de los productos básicos de alimentación.
#
# Los ingresos son escandalosamente insuficientes, la moneda presenta una devaluación considerable, muy poca producción nacional, esto y otras cosas nos continuarán conllevando a escenarios mencionados al inicio, sobre todo, falta de personal en el sector estatal (aún mayor).
#
# Nuestro país ha presentado recientemente un Programa de Gobierno, el cual esperamos que las acciones que traiga, impacte positivamente en la economía.
