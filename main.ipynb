# %%
import icd_module as icd

# %% [markdown]
# ![](img/data1.png)

# %% [markdown]
# <h1>Gráfico 1</h1>

# %%
icd.full_currency_graph()

# %% [markdown]
# ![](img/data2.png)

# %%
icd.means_table()
# Out:
# +--------------------+-------+-------+
# |  Últimos 3 meses   |  USD  |  EURO |
# +--------------------+-------+-------+
# |   Salario Medio    | 15.24 | 13.65 |
# |   Pensión Mínima   |  6.99 |  6.26 |
# | Estipendio 1er Año |  0.46 |  0.41 |
# +--------------------+-------+-------+

# %% [markdown]
# <h1>Gráfico 2</h1>

# %%
icd.rice_and_salary_graph()

# %% [markdown]
# <h1>Gráfico 3</h1>

# %%
icd.egg_employees_graph()

# %% [markdown]
# <h1>Gráfico 4</h1>

# %%
icd.rice_vs_minimum_pension()

# %% [markdown]
# <h1>Gráfico 5</h1>

# %%
icd.milk_beans_minpens()

# %% [markdown]
# <h1>Gráfico 6</h1>

# %%
icd.liquids_graph()
icd.soft_drink_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb4080a098a5a5e5490a6fdee93d948c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb4080a098a5a5e5490a6fdee93d948c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb4080a098a5a5e5490a6fdee93d948c = L.map(
#                 &quot;map_fb4080a098a5a5e5490a6fdee93d948c&quot;,
#                 {
#                     center: [23.0515757, -82.3304645],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_417020a0659fda4f0be755ed283b252e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_417020a0659fda4f0be755ed283b252e.addTo(map_fb4080a098a5a5e5490a6fdee93d948c);
#
#
#             var marker_f468746954dfffb5802daa82a212b7d0 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_fb4080a098a5a5e5490a6fdee93d948c);
#
#
#         var custom_icon_841300da479ce19b3c934d9077c71309 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_f468746954dfffb5802daa82a212b7d0.setIcon(custom_icon_841300da479ce19b3c934d9077c71309);
#
#
#         var popup_3fe4307ae16364a07367fa2ab732872a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b566bf2bfb0520adc653178e48e60a75 = $(`&lt;div id=&quot;html_b566bf2bfb0520adc653178e48e60a75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;1005&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_3fe4307ae16364a07367fa2ab732872a.setContent(html_b566bf2bfb0520adc653178e48e60a75);
#
#
#
#         marker_f468746954dfffb5802daa82a212b7d0.bindPopup(popup_3fe4307ae16364a07367fa2ab732872a)
#         ;
#
#
#
#
#             marker_f468746954dfffb5802daa82a212b7d0.bindTooltip(
#                 `&lt;div&gt;
#                      1005
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c8b606b1f1596d6acd9ef4da6d154c18 = L.marker(
#                 [23.139893, -82.399987],
#                 {
# }
#             ).addTo(map_fb4080a098a5a5e5490a6fdee93d948c);
#
#
#         var custom_icon_f009db541230b7ee3454a67eb1c46134 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_c8b606b1f1596d6acd9ef4da6d154c18.setIcon(custom_icon_f009db541230b7ee3454a67eb1c46134);
#
#
#         var popup_ea1de67076490980bb255a73b1f5fdf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f32f743e3dfcb079d8faf060ee2d49a2 = $(`&lt;div id=&quot;html_f32f743e3dfcb079d8faf060ee2d49a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;None&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_ea1de67076490980bb255a73b1f5fdf4.setContent(html_f32f743e3dfcb079d8faf060ee2d49a2);
#
#
#
#         marker_c8b606b1f1596d6acd9ef4da6d154c18.bindPopup(popup_ea1de67076490980bb255a73b1f5fdf4)
#         ;
#
#
#
#
#             var marker_36c05b7f32bf0a5101b2d27812c5870f = L.marker(
#                 [23.127062, -82.399987],
#                 {
# }
#             ).addTo(map_fb4080a098a5a5e5490a6fdee93d948c);
#
#
#         var custom_icon_78861b94c701c57a080b0feeb53025dd = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [30, 30],
# });
#         marker_36c05b7f32bf0a5101b2d27812c5870f.setIcon(custom_icon_78861b94c701c57a080b0feeb53025dd);
#
#
#         var popup_6e15acc4088dc2a65dcc5f181d1547d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72d1434bf99109eec7fbda88864f8fee = $(`&lt;div id=&quot;html_72d1434bf99109eec7fbda88864f8fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;h1&gt;Andrea&lt;/h1&gt;         &lt;/div&gt;`)[0];
#                 popup_6e15acc4088dc2a65dcc5f181d1547d6.setContent(html_72d1434bf99109eec7fbda88864f8fee);
#
#
#
#         marker_36c05b7f32bf0a5101b2d27812c5870f.bindPopup(popup_6e15acc4088dc2a65dcc5f181d1547d6)
#         ;
#
#
#
#
#             marker_36c05b7f32bf0a5101b2d27812c5870f.bindTooltip(
#                 `&lt;div&gt;
#                      Andrea
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c305fc09a98925ba0aa79712fb14050f = L.marker(
#                 [23.086112, -82.468054],
#                 {
# }
#             ).addTo(map_fb4080a098a5a5e5490a6fdee93d948c);
#
#
#         var custom_icon_81b80a5a6a05a1bc8a05217427bd8110 = L.icon({
#   &quot;iconUrl&quot;: &
